# %% [markdown]
# # Examples: Jupyter-Notebook

# %%
import sys
sys.path.append('../../../')
import qesolver as qe

# %% [markdown]
# Real case

# %%
a = 1
b = 2
c = -3
qe.run_quadraticEQSolver(a, b, c)
# Out:
# QUADRATIC EQUATION SOLVER:
# solving: 1*x^2+2*x+-3=0
#
# p = b/a = 2.0
# q = c/a = -3.0
#
# x^2+2.0*x+-3.0=0                         /--3.0 | on both sides
# x^2+2.0*x=3.0                            /+(p/2)^2 | completing the square
#
# x^2 + 2*2.0/2*x + (2.0/2)^2 = (2.0/2)^2 - -3.0 | bionomial formula
# (x+2.0/2)^2 = (2.0/2)^2 - -3.0           | sqrt() on both sides
# |x+2.0/2| = sqrt( (2.0/2)^2 - -3.0 )     | next solve absolute value
# x+2.0/2 = ±sqrt( (2.0/2)^2 - -3.0 )      / -2.0/2 | subtract p/2 from both sides
# x = -2.0/2 ± sqrt( (2.0/2)^2 - -3.0 )
#
# x1 = 1.00000000000000
# x2 = -3.00000000000000
# real

# %% [markdown]
# Complex case

# %%
a = 1
b = 2
c = 3
qe.run_quadraticEQSolver(a, b, c)
# Out:
# QUADRATIC EQUATION SOLVER:
# solving: 1*x^2+2*x+3=0
#
# p = b/a = 2.0
# q = c/a = 3.0
#
# x^2+2.0*x+3.0=0                          /-3.0 | on both sides
# x^2+2.0*x=-3.0                           /+(p/2)^2 | completing the square
#
# x^2 + 2*2.0/2*x + (2.0/2)^2 = (2.0/2)^2 - 3.0 | bionomial formula
# (x+2.0/2)^2 = (2.0/2)^2 - 3.0            | sqrt() on both sides
# |x+2.0/2| = sqrt( (2.0/2)^2 - 3.0 )      | next solve absolute value
# x+2.0/2 = ±sqrt( (2.0/2)^2 - 3.0 )       / -2.0/2 | subtract p/2 from both sides
# x = -2.0/2 ± sqrt( (2.0/2)^2 - 3.0 )
#
# x1 = -1.0 + 1.4142135623731*I
# x2 = -1.0 - 1.4142135623731*I
# complex

# %% [markdown]
# Symbolic calculation

# %%
a = 'r'
b = 's'
c = 't'
qe.run_quadraticEQSolver(a, b, c)
# Out:
# QUADRATIC EQUATION SOLVER:
# solving: r*x^2+s*x+t=0
#
# p = b/a = s/r
# q = c/a = t/r
#
# x^2+s/r*x+t/r=0                          /-t/r | on both sides
# x^2+s/r*x=-t/r                           /+(p/2)^2 | completing the square
#
# x^2 + 2*s/r/2*x + (s/r/2)^2 = (s/r/2)^2 - t/r | bionomial formula
# (x+s/r/2)^2 = (s/r/2)^2 - t/r            | sqrt() on both sides
# |x+s/r/2| = sqrt( (s/r/2)^2 - t/r )      | next solve absolute value
# x+s/r/2 = ±sqrt( (s/r/2)^2 - t/r )       / -s/r/2 | subtract p/2 from both sides
# x = -s/r/2 ± sqrt( (s/r/2)^2 - t/r )
#
# x1 = 0.5*(-s + 2.0*(-r*t + 0.25*s**2)**0.5)/r
# x2 = 0.5*(-s - 2.0*(-r*t + 0.25*s**2)**0.5)/r
